# %%
import cv2
import os
from matplotlib import pyplot as plt

# %%
img= cv2.imread("Images/JU-logo.png",cv2.IMREAD_GRAYSCALE)
plt.imshow(img)

# %%
img2=cv2.imread("Images/JU-logo.png",cv2.IMREAD_COLOR)
plt.imshow(img2)

# %%
cv2.imshow("Gray",img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imshow("Color",img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
path= r'C:\Users\Admin\Desktop'
os.chdir(path)

# %%
cv2.imwrite("newGray.jpg", img)
cv2.imwrite("newColor.jpg", img)
# Out:
# True

# %%
print(os.listdir(path))
# Out:
# ['1993.pdf', 'CodeBlocks.lnk', 'Copy of Emotion Dataset.csv', 'desktop.ini', 'DIP', 'Eclipse IDE for Java Developers - 2023-12.lnk', 'newColor.jpg', 'newGray.jpg', 'Old Firefox Data', 'Picture.png', 'portfolio', 'Visual Studio Code.lnk', 'WPS Office.lnk', 'WPS PDF.lnk', 'Zoom.lnk']
